# %% [markdown]
# # LAB ĐIỂM CỘNG

# %% [markdown]
# ## Python (15)

# %% [markdown]
# ### Q1 (1)
# Rename this file as `{fullname}.ipynb`.

# %%
import os
old_name = "/content/drive/MyDrive/PTDL&HS/lab+diem.ipynb"
new_name = "/content/drive/MyDrive/PTDL&HS/TranHungThinh.ipynb"

if os.path.exists(old_name):
  if old_name.endswith(".ipynb"):
    os.rename(old_name, new_name)
    print(f"Successfully renamed {old_name} to {new_name}")
  else:
    print(f"{old_name} is not a Jupyter Notebook file")
else:
  print(f"File {old_name} does not exist")
# Out:
# Successfully renamed /content/drive/MyDrive/PTDL&HS/lab+diem.ipynb to /content/drive/MyDrive/PTDL&HS/TranHungThinh.ipynb

# %% [markdown]
# ### Q2 (1)
# Create variable name `my_name` as string and assign your name to this variable.
# Print the `my_name`.

# %%
# Your code here
my_name = "TranHungThinh"
print(my_name)
# Out:
# TranHungThinh

# %% [markdown]
# ### Q3 (2)
# Develop class `CPStudent` with the following attributes
#
# - `student_id`:str -> vlu student id that start with `st`
# - `name`:str -> Name of the associated student
# - `score`:float -> Score of the midterm exam. The range is `[0.0, 100.0]`
#
# During the object creation, assign `student_id` and `name`. The `score` is set as `0.0` by default.
#
# `s1 = DAstudent('207CT20000', 'Mr. Jo')`

# %%
# Your code
class CPStudent:
    def __init__(self, student_id: str, name: str):
        self.student_id = student_id
        self.name = name
        self.score = 0.0

# %% [markdown]
# ### Q4 (2)
#
# Modify the class `DAStudent` to have function `LAB that takes `float` as the input.
# This function will assign the input to `DAStudent.score`.
#
# Example
#
# ```python
# s1.lab(50.5)
# print(s1.score)
# >>> 50.5
# ```
#
# ### Q5 (3)
#
# Check the correctness of the input. Inform the user when the input is wrong.
#
# *Hint: You will only get full mark if you use `raise`.*
#
# Example 1:
#
# ```python
# s1.lab(150)
# >>> ValueError: Some message
# ```
#
# Example 2:
#
# ```python
# s1.lab('150')
# >>> ValueError: Some message
# ```

# %%
# Your code
class DAStudent(CPStudent):
  def LAB(self, score):
    if isinstance(score, float) or isinstance(score, int):
      if not 0.0 <= score <= 100.0: raise ValueError("Lab score must be between 0.0 and 100.0")
      else: self.score = score
    else: raise ValueError("Wrong data type")

# %%
s1 = DAStudent('207CT20000', 'Mr. Jo')

# %%
s1.LAB(50.5)
print(s1.score)
# Out:
# 50.5

# %%
s1.LAB(150)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-f4576411b155> in <cell line: 1>()
# ----> 1 s1.LAB(150)
#
# <ipython-input-44-c5dd27a34654> in LAB(self, score)
#       3   def LAB(self, score):
#       4     if isinstance(score, float) or isinstance(score, int):
# ----> 5       if not 0.0 <= score <= 100.0: raise ValueError("Lab score must be between 0.0 and 100.0")
#       6       else: self.score = score
#       7     else: raise ValueError("Wrong data type")
#
# ValueError: Lab score must be between 0.0 and 100.0

# %%
s1.LAB("150")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-c7a012b5b018> in <cell line: 1>()
# ----> 1 s1.LAB("150")
#
# <ipython-input-44-c5dd27a34654> in LAB(self, score)
#       5       if not 0.0 <= score <= 100.0: raise ValueError("Lab score must be between 0.0 and 100.0")
#       6       else: self.score = score
# ----> 7     else: raise ValueError("Wrong data type")
#
# ValueError: Wrong data type

# %% [markdown]
# ### Q6 (6)
#
# Once upon a time in the magical land, there are two engineer beavers living together.
#
#
# Their hobby is to build a dam out of wood.
#
#
# Years and years, dam after another dam, one of engineer beaver get bored. The beaver wants a better life. A more accurate calculation of dam not just keep building it anymore.
#
#
# Now, they are deploying a rain sensor to collect data which will be used to predict water level of the river.
#
# Finally, with their new skill set and hardworking, a predictor is obtained. They named their invention `The Oracle of the Dam (TOTD)`.
#
# However, the `TOTD` only predicts the water level.
#
# The engineer/data scientist beavers still needs to build the dam themselves but this time, it will be the most efficient dam of the beaver land ever.
#
# Every 2 meters of the water level, the dam needs to be build 1 level higher. And every log (*) uses will cost $3.5.
#
# Here is how the 3-level dam look like from the cross section view
#
# ```
# l_3   *
# l_2  ***
# l_1 *****
# ```
#
# Here is how much this project will cost
#
# ```
# Number of logs: 9
# Cost: $31.5
# ```
#
#
# Your task is simple, write a function `dam_design` that takes `water_level` as an input. Print the design of the dam and summarize the material and cost.
#
# Example 1:
# ```python
# dam_design(0)
# >>> *
# >>> Number of logs: 1
# >>> Cost: $3.5
# ```
#
# Example 2:
# ```python
# dam_design(1)
# >>> *
# >>> Number of logs: 1
# >>> Cost: $3.5
# ```
#
# Example 3:
# ```python
# dam_design(2)
# >>>  *
# >>> ***
# >>> Number of logs: 4
# >>> Cost: $14.0
# ```
#
# Example 4:
# ```python
# dam_design(3)
# >>>  *
# >>> ***
# >>> Number of logs: 4
# >>> Cost: $14.0
# ```
#
# Example 5:
# ```python
# dam_design(4)
# >>>   *
# >>>  ***
# >>> *****
# >>> Number of logs: 9
# >>> Cost: $31.5
# ```

# %%
# Your code
def dam_design(water_level):
    num_logs = water_level // 2
    cost = num_logs * 3.5
    for i in range(1, water_level + 1):
        print(" " * (water_level - i), "*" * (2 * i - 1))

    print(f"Number of logs: {num_logs}")
    print(f"Cost: ${cost:.1f}")

dam_design(0)
dam_design(1)
dam_design(2)
dam_design(3)
dam_design(4)
# Out:
# Number of logs: 1
# Cost: $3.5
#  *
# Number of logs: 1
# Cost: $3.5
#   *
#  ***
# Number of logs: 2
# Cost: $7.0
#    *
#   ***
#  *****
# Number of logs: 2
# Cost: $7.0
#     *
#    ***
#   *****
#  *******
# Number of logs: 3
# Cost: $10.5
